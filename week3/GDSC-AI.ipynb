# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# ''

# %%
# 安裝套件

# !pip install seaborn==0.9
# !pip install facets-overview
# !pip install keras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting seaborn==0.9
#   Downloading seaborn-0.9.0-py3-none-any.whl (208 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.1/208.1 KB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.15.2 in /usr/local/lib/python3.8/dist-packages (from seaborn==0.9) (1.3.5)
# Requirement already satisfied: matplotlib>=1.4.3 in /usr/local/lib/python3.8/dist-packages (from seaborn==0.9) (3.5.3)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from seaborn==0.9) (1.7.3)
# Requirement already satisfied: numpy>=1.9.3 in /usr/local/lib/python3.8/dist-packages (from seaborn==0.9) (1.22.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.3->seaborn==0.9) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.3->seaborn==0.9) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.3->seaborn==0.9) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.3->seaborn==0.9) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.3->seaborn==0.9) (23.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.3->seaborn==0.9) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.3->seaborn==0.9) (8.4.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.15.2->seaborn==0.9) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->seaborn==0.9) (1.15.0)
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
# Successfully installed seaborn-0.9.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting facets-overview
#   Downloading facets_overview-1.1.0-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from facets-overview) (1.22.4)
# Collecting protobuf>=3.20.0
#   Downloading protobuf-4.22.0-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.4/302.4 KB 26.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.8/dist-packages (from facets-overview) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.22.0->facets-overview) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.22.0->facets-overview) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=0.22.0->facets-overview) (1.15.0)
# Installing collected packages: protobuf, facets-overview
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.22.0 which is incompatible.
# tensorflow-metadata 1.12.0 requires protobuf<4,>=3.13, but you have protobuf 4.22.0 which is incompatible.
# tensorboard 2.11.2 requires protobuf<4,>=3.9.2, but you have protobuf 4.22.0 which is incompatible.
# Successfully installed facets-overview-1.1.0 protobuf-4.22.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras in /usr/local/lib/python3.8/dist-packages (2.11.0)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import seaborn as sns
from google.colab import widgets
from IPython.core.display import display, HTML
import base64
from facets_overview.feature_statistics_generator import FeatureStatisticsGenerator

# %% [markdown]
# ### Step1. 讀入資料
# 把 adult.data 和 adult.test 上傳，並且讀入他們，方法如下。
#
# ```python
# train_df = pd.read_csv("{你的 adult.data 路徑}", names=COLUMNS, sep=r'\s*,\s*', engine='python', na_values="?")
# test_df = pd.read_csv("{你的 adult.test 路徑}", names=COLUMNS, sep=r'\s*,\s*', skiprows=[0], engine='python', na_values="?")
# ```
# 之後，我們合併兩個資料一起進行前處理。

# %%
COLUMNS = ["age 年齡",
           "workclass 工作類別",
           "fnlwgt 序號",
           "education 教育程度",
           "education_num 教育時間",
           "marital_status 婚姻",
           "occupation 職業",
           "relationship 社會角色",
           "race 種族",
           "gender 性別",
           "capital_gain 資本收益",
           "capital_loss 資本損失",
           "hours_per_week 每週工作時間",
           "native_country 國籍",
           "income_bracket 收入"]

train_df = pd.read_csv(
    "/content/drive/MyDrive/GDSC-AI/adult.data",
    names=COLUMNS,
    sep=r'\s*,\s*',
    engine='python',
    na_values="?")
test_df = pd.read_csv(
    "/content/drive/MyDrive/GDSC-AI/adult.test",
    names=COLUMNS,
    sep=r'\s*,\s*',
    skiprows=[0],
    engine='python',
    na_values="?")

alldata_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)
print(len(train_df))
print(len(test_df))
print(len(alldata_df))
alldata_df

# Keep the original dataset
alldata_df_original = alldata_df.copy()
# Out:
# 32561
# 16281
# 48842

# %%
#@title 資料視覺化

def data_visualize(df):
  fsg = FeatureStatisticsGenerator()
  dataframes = [
      {'table': df, 'name': 'Data'}]
  censusProto = fsg.ProtoFromDataFrames(dataframes)
  protostr = base64.b64encode(censusProto.SerializeToString()).decode("utf-8")

  HTML_TEMPLATE = """<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
          <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
          <facets-overview id="elem"></facets-overview>
          <script>
            document.querySelector("#elem").protoInput = "{protostr}";
          </script>"""

  html = HTML_TEMPLATE.format(protostr=protostr)
  display(HTML(html))

data_visualize(alldata_df)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
#           <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
#           <facets-overview id="elem"></facets-overview>
#           <script>
#             document.querySelector("#elem").protoInput = "...";
#           </script>

# %% [markdown]
# ### Step2. 資料前處理 Data Pre-processing
# 進行重要的資料前處理。
#
# 資料前處理有很多方法，以下主要示範以下三種：
# - 空缺值補齊
# - 區間分群
# - One-hot encoding
#
# ---
# **1. 空缺值補齊**
#
# 經過剛剛的資料視覺化，我們發現有缺值的變數 (Variables) 有：
# - workclass
# - occupation
# - native_country
#
# 填值時並非隨意填補，我們必須有邏輯的思考如何補齊空值。
#
# **2. 區間分群**
#
# 有時候數值資料 (Numerical data) 可以透過一個區間一個區間的分群，減少雜訊的量，有時也能降低模型負擔。
#
# 我們會針對 age 類別進行分群(如：青年一群、壯年一群、老年一群等)
#
# ```python
# alldata_df["age_group"]=alldata_df["age 年齡"]
# alldata_df["age_group"] = pd.cut(alldata_df["age_group"],bins=[16,27,37,47,57,67,77,90],labels=[0,1,2,3,4,5,6])
# ```
#
# **3. One-hot encoding**
# 類別型資料 (Categorical data) 對於 NN 來說相對較難直接處理，我們透過編碼讓他轉換成容易處理的格式， One-hot 編碼的原理如下：
#
# ```python
# 假設今天有一個類別 "fruit" ，裏面有三種值 ['apple', 'banana', 'cherry']
# One-hot 的原理就是：當機器看到 'apple' 時就把他看成 '第1個' ，依此類推。
#
# 所以，如果是 '第1個(apple)' 的話，我們就編碼成 [1, 0, 0]
# 如果是 '第2個(banana)' 的話，我們就編碼成 [0, 1, 0]
# 如果是 '第3個(cherry)' 的話，我們就編碼成 [0, 0, 1]
#
# ```
#
# ```python
# # One-hot encoding
# useddata_df_onehot = pd.get_dummies(useddata_df)
# cols = useddata_df_onehot.columns
#
# ```

# %%
# 將 workclass 和 occupation 的資料視覺化，觀察兩者關係

sns.heatmap(alldata_df.groupby(['workclass 工作類別', 'occupation 職業']).size().unstack(level=0),
            vmax=1000,
            annot=True,
            fmt="g"
            )
plt.xticks(rotation=45)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5]),
#  [Text(0.5, 0, 'Federal-gov'),
#   Text(1.5, 0, 'Local-gov'),
#   Text(2.5, 0, 'Private'),
#   Text(3.5, 0, 'Self-emp-inc'),
#   Text(4.5, 0, 'Self-emp-not-inc'),
#   Text(5.5, 0, 'State-gov'),
#   Text(6.5, 0, 'Without-pay')])
# /usr/local/lib/python3.8/dist-packages/IPython/core/events.py:88: UserWarning: Glyph 24037 (\N{CJK UNIFIED IDEOGRAPH-5DE5}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/IPython/core/events.py:88: UserWarning: Glyph 20316 (\N{CJK UNIFIED IDEOGRAPH-4F5C}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/IPython/core/events.py:88: UserWarning: Glyph 39006 (\N{CJK UNIFIED IDEOGRAPH-985E}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/IPython/core/events.py:88: UserWarning: Glyph 21029 (\N{CJK UNIFIED IDEOGRAPH-5225}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/IPython/core/events.py:88: UserWarning: Glyph 32887 (\N{CJK UNIFIED IDEOGRAPH-8077}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/IPython/core/events.py:88: UserWarning: Glyph 26989 (\N{CJK UNIFIED IDEOGRAPH-696D}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 24037 (\N{CJK UNIFIED IDEOGRAPH-5DE5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 20316 (\N{CJK UNIFIED IDEOGRAPH-4F5C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 39006 (\N{CJK UNIFIED IDEOGRAPH-985E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 21029 (\N{CJK UNIFIED IDEOGRAPH-5225}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 32887 (\N{CJK UNIFIED IDEOGRAPH-8077}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 26989 (\N{CJK UNIFIED IDEOGRAPH-696D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#@title 補齊 workclass

alldata_df['workclass 工作類別'].fillna(value='Private', inplace=True)
alldata_df.info()

alldata_df.loc[alldata_df['occupation 職業'].isnull(), 'workclass 工作類別'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   age 年齡                 48842 non-null  int64
#  1   workclass 工作類別         48842 non-null  object
#  2   fnlwgt 序號              48842 non-null  int64
#  3   education 教育程度         48842 non-null  object
#  4   education_num 教育時間     48842 non-null  int64
#  5   marital_status 婚姻      48842 non-null  object
#  6   occupation 職業          46033 non-null  object
#  7   relationship 社會角色      48842 non-null  object
#  8   race 種族                48842 non-null  object
#  9   gender 性別              48842 non-null  object
#  10  capital_gain 資本收益      48842 non-null  int64
#  11  capital_loss 資本損失      48842 non-null  int64
#  12  hours_per_week 每週工作時間  48842 non-null  int64
#  13  native_country 國籍      47985 non-null  object
#  14  income_bracket 收入      48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB
# array(['Private', 'Never-worked'], dtype=object)

# %%
#@title 補齊 occupation

workclasses = alldata_df['workclass 工作類別'].unique()

# 用相同工作類別中職業的眾數(mode)填值
occupation_mode = alldata_df.groupby('workclass 工作類別')['occupation 職業'].apply(pd.Series.mode)

for workclass in workclasses:
  if (workclass != "Never-worked"): # 記得區分出無工作者
    alldata_df.loc[(alldata_df['occupation 職業'].isnull()) & (alldata_df['workclass 工作類別'] == workclass), 'occupation 職業'] = occupation_mode[workclass][0]
  else:
    alldata_df.loc[(alldata_df['occupation 職業'].isnull()) & (alldata_df['workclass 工作類別'] == workclass), 'occupation 職業'] = "Never-worked"

alldata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   age 年齡                 48842 non-null  int64
#  1   workclass 工作類別         48842 non-null  object
#  2   fnlwgt 序號              48842 non-null  int64
#  3   education 教育程度         48842 non-null  object
#  4   education_num 教育時間     48842 non-null  int64
#  5   marital_status 婚姻      48842 non-null  object
#  6   occupation 職業          48842 non-null  object
#  7   relationship 社會角色      48842 non-null  object
#  8   race 種族                48842 non-null  object
#  9   gender 性別              48842 non-null  object
#  10  capital_gain 資本收益      48842 non-null  int64
#  11  capital_loss 資本損失      48842 non-null  int64
#  12  hours_per_week 每週工作時間  48842 non-null  int64
#  13  native_country 國籍      47985 non-null  object
#  14  income_bracket 收入      48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
fig, ax = plt.subplots(figsize=(10,20))   # 調整大小
sns.heatmap(alldata_df.groupby(['race 種族', 'native_country 國籍']).size().unstack(level=0),
            vmax=100,
            annot=True,
            fmt=".0f"
            )
plt.xticks(rotation=30)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5]),
#  [Text(0.5, 0, 'Amer-Indian-Eskimo'),
#   Text(1.5, 0, 'Asian-Pac-Islander'),
#   Text(2.5, 0, 'Black'),
#   Text(3.5, 0, 'Other'),
#   Text(4.5, 0, 'White')])
# /usr/local/lib/python3.8/dist-packages/IPython/core/events.py:88: UserWarning: Glyph 31278 (\N{CJK UNIFIED IDEOGRAPH-7A2E}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/IPython/core/events.py:88: UserWarning: Glyph 26063 (\N{CJK UNIFIED IDEOGRAPH-65CF}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/IPython/core/events.py:88: UserWarning: Glyph 22283 (\N{CJK UNIFIED IDEOGRAPH-570B}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/IPython/core/events.py:88: UserWarning: Glyph 31821 (\N{CJK UNIFIED IDEOGRAPH-7C4D}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 31278 (\N{CJK UNIFIED IDEOGRAPH-7A2E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 26063 (\N{CJK UNIFIED IDEOGRAPH-65CF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 22283 (\N{CJK UNIFIED IDEOGRAPH-570B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 31821 (\N{CJK UNIFIED IDEOGRAPH-7C4D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#@title 補齊 native_country

alldata_df['native_country 國籍'].fillna(value='United-States', inplace=True)
alldata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   age 年齡                 48842 non-null  int64
#  1   workclass 工作類別         48842 non-null  object
#  2   fnlwgt 序號              48842 non-null  int64
#  3   education 教育程度         48842 non-null  object
#  4   education_num 教育時間     48842 non-null  int64
#  5   marital_status 婚姻      48842 non-null  object
#  6   occupation 職業          48842 non-null  object
#  7   relationship 社會角色      48842 non-null  object
#  8   race 種族                48842 non-null  object
#  9   gender 性別              48842 non-null  object
#  10  capital_gain 資本收益      48842 non-null  int64
#  11  capital_loss 資本損失      48842 non-null  int64
#  12  hours_per_week 每週工作時間  48842 non-null  int64
#  13  native_country 國籍      48842 non-null  object
#  14  income_bracket 收入      48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
#@title 年齡分群

alldata_df["age_group"]=alldata_df["age 年齡"] #先複製一欄出來，不要改動到原始資料
alldata_df["age_group"] = pd.cut(alldata_df["age_group"],bins=[16,27,37,47,57,67,77,90],labels=[0,1,2,3,4,5,6])

alldata_df["age_group"]
# Out:
# 0        2
# 1        3
# 2        2
# 3        3
# 4        1
#         ..
# 48837    2
# 48838    4
# 48839    2
# 48840    2
# 48841    1
# Name: age_group, Length: 48842, dtype: category
# Categories (7, int64): [0 < 1 < 2 < 3 < 4 < 5 < 6]

# %%
#@title 收入二元化

#我們讓年收>50K設為1，否則為0

alldata_df.loc[(alldata_df['income_bracket 收入'] == '>50K') | (alldata_df['income_bracket 收入'] == '>50K.'), 'salary_bin'] = 1
alldata_df['salary_bin'].fillna(0, inplace=True)

#data_visualize(alldata_df)
# alldata_df['salary_bin']
alldata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   age 年齡                 48842 non-null  int64
#  1   workclass 工作類別         48842 non-null  object
#  2   fnlwgt 序號              48842 non-null  int64
#  3   education 教育程度         48842 non-null  object
#  4   education_num 教育時間     48842 non-null  int64
#  5   marital_status 婚姻      48842 non-null  object
#  6   occupation 職業          48842 non-null  object
#  7   relationship 社會角色      48842 non-null  object
#  8   race 種族                48842 non-null  object
#  9   gender 性別              48842 non-null  object
#  10  capital_gain 資本收益      48842 non-null  int64
#  11  capital_loss 資本損失      48842 non-null  int64
#  12  hours_per_week 每週工作時間  48842 non-null  int64
#  13  native_country 國籍      48842 non-null  object
#  14  income_bracket 收入      48842 non-null  object
#  15  age_group              48842 non-null  category
#  16  salary_bin             48842 non-null  float64
# dtypes: category(1), float64(1), int64(6), object(9)
# memory usage: 6.0+ MB

# %%
# 0   age 年齡                 48842 non-null  int64 
# 1   workclass 工作類別         48842 non-null  object
# 2   fnlwgt 序號              48842 non-null  int64 
# 3   education 教育程度         48842 non-null  object
# 4   education_num 教育時間     48842 non-null  int64 
# 5   marital_status 婚姻      48842 non-null  object
# 6   occupation 職業          46043 non-null  object
# 7   relationship 社會角色      48842 non-null  object
# 8   race 種族                48842 non-null  object
# 9   gender 性別              48842 non-null  object
# 10  capital_gain 資本收益      48842 non-null  int64 
# 11  capital_loss 資本損失      48842 non-null  int64 
# 12  hours_per_week 每週工作時間  48842 non-null  int64 
# 13  native_country 國籍      48842 non-null  object
# 14  income_bracket 收入      48842 non-null  object
# 15  age_group              48842 non-null  int64 
# 16  salary_bin             48842 non-null  int64 


#我們只選擇我們需要的參數進行訓練

used_variables = ['age_group', 'workclass 工作類別', 'education 教育程度', 'education_num 教育時間', 'marital_status 婚姻', 'occupation 職業', 'relationship 社會角色', 'race 種族', 'capital_gain 資本收益', 'capital_loss 資本損失', 'hours_per_week 每週工作時間', 'native_country 國籍']
label = 'salary_bin'
useddata_df = pd.DataFrame()

for variable in used_variables:
  useddata_df[variable] = alldata_df[variable]
useddata_df[label] = alldata_df[label]

useddata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   age_group              48842 non-null  category
#  1   workclass 工作類別         48842 non-null  object
#  2   education 教育程度         48842 non-null  object
#  3   education_num 教育時間     48842 non-null  int64
#  4   marital_status 婚姻      48842 non-null  object
#  5   occupation 職業          48842 non-null  object
#  6   relationship 社會角色      48842 non-null  object
#  7   race 種族                48842 non-null  object
#  8   capital_gain 資本收益      48842 non-null  int64
#  9   capital_loss 資本損失      48842 non-null  int64
#  10  hours_per_week 每週工作時間  48842 non-null  int64
#  11  native_country 國籍      48842 non-null  object
#  12  salary_bin             48842 non-null  float64
# dtypes: category(1), float64(1), int64(4), object(7)
# memory usage: 4.5+ MB

# %%
#@title One-hot encoding

useddata_df_onehot = pd.get_dummies(useddata_df)
cols = useddata_df_onehot.columns

data_visualize(useddata_df_onehot)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
#           <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
#           <facets-overview id="elem"></facets-overview>
#           <script>
#             document.querySelector("#elem").protoInput = "...";
#           </script>

# %%
#@title 把剛剛上面的前處理全部包成函數

def preprocessing(alldata_df):

  # 補齊 workclass
  alldata_df['workclass 工作類別'].fillna(value='Private', inplace=True)
  alldata_df.loc[alldata_df['occupation 職業'].isnull(), 'workclass 工作類別'].unique()

  # 補齊 occupation
  workclasses = alldata_df['workclass 工作類別'].unique()

  # 用相同工作類別中職業的眾數(mode)填值
  occupation_mode = alldata_df.groupby('workclass 工作類別')['occupation 職業'].apply(pd.Series.mode)

  for workclass in workclasses:
    if (workclass != "Never-worked"): # 記得區分出無工作者
      alldata_df.loc[(alldata_df['occupation 職業'].isnull()) & (alldata_df['workclass 工作類別'] == workclass), 'occupation 職業'] = occupation_mode[workclass][0]
    else:
      alldata_df.loc[(alldata_df['occupation 職業'].isnull()) & (alldata_df['workclass 工作類別'] == workclass), 'occupation 職業'] = "Never-worked"


  # 補齊 native_country
  alldata_df['native_country 國籍'].fillna(value='United-States', inplace=True)

  # 年齡分群
  alldata_df["age_group"]=alldata_df["age 年齡"] #先複製一欄出來，不要改動到原始資料
  alldata_df["age_group"] = pd.cut(alldata_df["age_group"],bins=[16,27,37,47,57,67,77,90],labels=[0,1,2,3,4,5,6])

  # 收入二元化
  alldata_df.loc[(alldata_df['income_bracket 收入'] == '>50K') | (alldata_df['income_bracket 收入'] == '>50K.'), 'salary_bin'] = 1
  alldata_df['salary_bin'].fillna(0, inplace=True)

  used_variables = ['age_group', 'workclass 工作類別', 'education 教育程度', 'education_num 教育時間', 'marital_status 婚姻', 'occupation 職業', 'relationship 社會角色', 'race 種族', 'capital_gain 資本收益', 'capital_loss 資本損失', 'hours_per_week 每週工作時間', 'native_country 國籍']
  label = 'salary_bin'
  useddata_df = pd.DataFrame()

  for variable in used_variables:
    useddata_df[variable] = alldata_df[variable]
  useddata_df[label] = alldata_df[label]

  useddata_df.info()

  # One-hot encoding
  useddata_df_onehot = pd.get_dummies(useddata_df)
  cols = useddata_df_onehot.columns

  # X_test = useddata_df_onehot.iloc[32561:,:].drop('salary_bin', axis=1).values
  return useddata_df_onehot

# %%
#@title 分成 X_train, Y_train, X_test, Y_test, X_val, Y_cal

from sklearn.model_selection import train_test_split

# len(train_df) = 32561
# len(test_df) = 16281

X_train = useddata_df_onehot.iloc[:32561,:].drop('salary_bin', axis=1).values
X_test = useddata_df_onehot.iloc[32561:,:].drop('salary_bin', axis=1).values
Y_train = useddata_df_onehot.iloc[:32561,:]['salary_bin'].values
Y_test = useddata_df_onehot.iloc[32561:,:]['salary_bin'].values


# Or, you can just call preprocessing function!
# preprocessed_data = preprocessing(alldata_df_original)
# X_train = preprocessed_data.iloc[:32561,:].drop('salary_bin', axis=1).values
# X_test = preprocessed_data.iloc[32561:,:].drop('salary_bin', axis=1).values
# Y_train = preprocessed_data.iloc[:32561,:]['salary_bin'].values
# Y_test = preprocessed_data.iloc[32561:,:]['salary_bin'].values


X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, shuffle=True)

print(len(X_train))
print(len(X_val))
print(len(X_test))
print(len(Y_train))
print(len(Y_val))
print(len(Y_test))
# Out:
# 26048
# 6513
# 16281
# 26048
# 6513
# 16281

# %% [markdown]
# ### Step3. 訓練
# 訓練這個大項目中，會有4個步驟：
#
# 1. 選定模型
# 2. 建模： `model.add()`
# 3. 編譯模型： `model.compile()`
# 4. 訓練模型： `model.fit()`

# %%
from keras import models
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

# %%
# plot history function

def history_plt(history):
  print("val_acc: {}".format(history.history['val_accuracy'][-1]))
  print("val_loss: {}".format(history.history['val_loss'][-1]))
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('Accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'validation'])
  plt.show()

  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('Loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'validation'])
  plt.show()

# %%
#@title First Model

run_this_model=1  #1: 訓練這個模型; 0: 跳過此段落

if(run_this_model):

  # 建模
  model = models.Sequential()             # Sequential 類神經網路模型

  # Input layer
  # is added automatically by keras.

  # Hidden Layers
  model.add(Dense(units=128,    # 神經元數目
                  input_dim=X_train.shape[1],     # 第一層隱藏層要設定 input_dim 當作是輸入層的神經元數目
                  activation='relu'   # relu 是活化函數的一種
                  ))
  
  model.add(Dense(units=128, activation='relu'))  # 第二層隱藏層開始就不用設定輸入數目了
  model.add(Dense(units=128, activation='relu'))

  # Output Layer
  model.add(Dense(units=1, activation='sigmoid')) # Sigmoid 是活化函數的一種

  # 編譯
  optimizer = Adam(learning_rate=0.01)    # Adam 是梯度下降法的一種，設定學習率
  model.compile(optimizer=optimizer,          # 引入剛剛設定好的梯度下降法
                loss='binary_crossentropy',   # 交叉熵 (crossentropy) 是一種損失函數
                metrics=['accuracy'])         # 判斷模型性能的目標參數
  
  model.summary()

  # 訓練
  history1 = model.fit(X_train,   # 訓練資料題目
                       Y_train,   # 訓練資料答案
                       batch_size=4096,   # 一次訓練的量
                       epochs=100,        # 訓練總代數
                       verbose=1,         # 是否顯示訓練過程
                       validation_data=[X_val,Y_val])    # 驗證資料

  # 印出訓練軌跡
  history_plt(history1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               14080
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 47,233
# Trainable params: 47,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 1s 85ms/step - loss: 92.5327 - accuracy: 0.5026 - val_loss: 28.2647 - val_accuracy: 0.7559
# Epoch 2/100
# 7/7 [==============================] - 0s 47ms/step - loss: 7.2716 - accuracy: 0.7757 - val_loss: 2.6468 - val_accuracy: 0.7777
# Epoch 3/100
# 7/7 [==============================] - 0s 47ms/step - loss: 6.4298 - accuracy: 0.7804 - val_loss: 6.6148 - val_accuracy: 0.7772
# Epoch 4/100
# 7/7 [==============================] - 0s 41ms/step - loss: 3.3737 - accuracy: 0.7778 - val_loss: 1.0649 - val_accuracy: 0.7761
# Epoch 5/100
# 7/7 [==============================] - 0s 45ms/step - loss: 2.4196 - accuracy: 0.7778 - val_loss: 4.9747 - val_accuracy: 0.7774
# Epoch 6/100
# 7/7 [==============================] - 0s 42ms/step - loss: 3.4694 - accuracy: 0.7857 - val_loss: 7.4540 - val_accuracy: 0.7593
# Epoch 7/100
# 7/7 [==============================] - 0s 27ms/step - loss: 2.4433 - accuracy: 0.8063 - val_loss: 1.4637 - val_accuracy: 0.8171
# Epoch 8/100
# 7/7 [==============================] - 0s 31ms/step - loss: 1.2623 - accuracy: 0.8164 - val_loss: 1.3365 - val_accuracy: 0.8173
# Epoch 9/100
# 7/7 [==============================] - 0s 28ms/step - loss: 1.1356 - accuracy: 0.8169 - val_loss: 0.9138 - val_accuracy: 0.8139
# Epoch 10/100
# 7/7 [==============================] - 0s 30ms/step - loss: 1.0409 - accuracy: 0.8235 - val_loss: 0.9152 - val_accuracy: 0.8139
# Epoch 11/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.6787 - accuracy: 0.8227 - val_loss: 0.5531 - val_accuracy: 0.8156
# Epoch 12/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0
100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2939 - accuracy: 0.8661 - val_loss: 0.3631 - val_accuracy: 0.8291
# Epoch 94/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.2974 - accuracy: 0.8643 - val_loss: 0.3672 - val_accuracy: 0.8409
# Epoch 95/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2980 - accuracy: 0.8648 - val_loss: 0.3548 - val_accuracy: 0.8386
# Epoch 96/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2994 - accuracy: 0.8662 - val_loss: 0.3633 - val_accuracy: 0.8369
# Epoch 97/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2979 - accuracy: 0.8646 - val_loss: 0.3514 - val_accuracy: 0.8495
# Epoch 98/100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2924 - accuracy: 0.8694 - val_loss: 0.3516 - val_accuracy: 0.8422
# Epoch 99/100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2911 - accuracy: 0.8695 - val_loss: 0.3510 - val_accuracy: 0.8415
# Epoch 100/100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2898 - accuracy: 0.8674 - val_loss: 0.3628 - val_accuracy: 0.8326
# val_acc: 0.8326424360275269
# val_loss: 0.3628435730934143

# %%
#@title Second Model

run_this_model=0

if(run_this_model):
  optimizer = Adam(learning_rate=0.03)
  model = models.Sequential()
  model.add(Dense(units=256, input_dim=X_train.shape[1], activation='relu'))
  model.add(Dense(units=2000, activation='relu'))
  model.add(Dense(units=2000, activation='relu'))
  model.add(Dense(units=256, activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  
  model.summary()

  history2 = model.fit(X_train, Y_train, batch_size=4096, epochs=50, verbose=1, 
                      validation_data=[X_val,Y_val])
  history_plt(history2)

# %%
#@title Third Model

run_this_model=0

if(run_this_model):
  optimizer = Adam(learning_rate=0.01)
  model = models.Sequential()
  model.add(Dense(units=256, input_dim=X_train.shape[1], activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units=256, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(units=1, activation='sigmoid'))
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.summary()

  history3 = model.fit(X_train, Y_train, batch_size=4096, epochs=150, verbose=0, 
                      validation_data=[X_val,Y_val])

  history_plt(history3)

# %%
#@title Find the best accuracy
do_find_best = 0

if(do_find_best):
  learning_rate = [0.01, 0.003, 0.0001]
  epochs = [50, 100, 150, 200]
  layers = [3, 4, 5]
  history=[]
  best_acc=0
  for l in learning_rate:
    for e in epochs:
      for la in layers:
        optimizer = Adam(learning_rate=l)
        model = models.Sequential()
        model.add(Dense(units=256, input_dim=X_train.shape[1], activation='relu'))
        model.add(Dropout(0.3))
        for i in range(la-1):
          model.add(Dense(units=256, input_dim=X_train.shape[1], activation='relu'))
          model.add(Dropout(0.3))
        model.add(Dense(units=1, activation='sigmoid'))
        model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
        model.summary()
        history_tmp=model.fit(X_train, Y_train, batch_size=4096, epochs=e, verbose=0, 
                            validation_data=[X_val,Y_val])
        history.append(history_tmp)
        history_plt(history_tmp)
        if(history_tmp.history['val_accuracy'][-1]>best_acc):
          best_acc=history_tmp.history['val_accuracy'][-1]
          best_settings = [l, e, la]

# %%
#@title Fourth Model
run_this_model=0

if (run_this_model):
  best_settings = [0.01, 100, 3]

  print(best_settings)

  optimizer = Adam(learning_rate=best_settings[0])
  model = models.Sequential()

  # Hidden Layer
  model.add(Dense(units=256, input_dim=X_train.shape[1], activation='relu'))
  model.add(Dropout(0.3))

  for i in range(best_settings[2]-1):
    model.add(Dense(units=256, activation='relu'))
    model.add(Dropout(0.3))

  # Output Layer
  model.add(Dense(units=1, activation='sigmoid'))

  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  model.summary()

  history4 = model.fit(X_train, Y_train, batch_size=4096, epochs=best_settings[1], verbose=1, 
                      validation_data=[X_val,Y_val])
  history_plt(history4)

# %%
#@title Best Model

from tensorflow.keras import regularizers

optimizer = Adam(learning_rate=0.002)
model = models.Sequential()

# Hidden Layer
model.add(Dense(units=128,
                input_dim=X_train.shape[1],
                activity_regularizer=regularizers.L2(0.0005),
                activation='relu'))
model.add(Dropout(0.3))

# model.add(Dense(units=128,
#                 activity_regularizer=regularizers.L2(0.001),
#                 activation='relu'))
# model.add(Dropout(0.3))

model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

history5 = model.fit(X_train, 
                     Y_train, 
                     batch_size=2000, 
                     epochs=100, 
                     verbose=1,
                     shuffle=True,
                     validation_data=[X_val,Y_val])
history_plt(history5)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 128)               14080
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 14,209
# Trainable params: 14,209
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 14/14 [==============================] - 1s 21ms/step - loss: 13725.8398 - accuracy: 0.6389 - val_loss: 9383.6426 - val_accuracy: 0.7772
# Epoch 2/100
# 14/14 [==============================] - 0s 13ms/step - loss: 7943.7046 - accuracy: 0.7290 - val_loss: 5350.0293 - val_accuracy: 0.7772
# Epoch 3/100
# 14/14 [==============================] - 0s 12ms/step - loss: 4521.1709 - accuracy: 0.7244 - val_loss: 3061.2295 - val_accuracy: 0.7788
# Epoch 4/100
# 14/14 [==============================] - 0s 11ms/step - loss: 2450.2349 - accuracy: 0.7625 - val_loss: 1543.0055 - val_accuracy: 0.7857
# Epoch 5/100
# 14/14 [==============================] - 0s 13ms/step - loss: 1284.2478 - accuracy: 0.7712 - val_loss: 853.1927 - val_accuracy: 0.7982
# Epoch 6/100
# 14/14 [==============================] - 0s 12ms/step - loss: 721.4678 - accuracy: 0.7879 - val_loss: 471.5763 - val_accuracy: 0.8161
# Epoch 7/100
# 14/14 [==============================] - 0s 13ms/step - loss: 392.9652 - accuracy: 0.8024 - val_loss: 252.8337 - val_accuracy: 0.8185
# Epoch 8/100
# 14/14 [==============================] - 0s 12ms/step - loss: 198.3658 - accuracy: 0.8074 - val_loss: 114.6092 - val_accuracy: 0.8176
# Epoch 9/100
# 14/14 [==============================] - 0s 11ms/step - loss: 85.7930 - accuracy: 0.8133 - val_loss: 47.3363 - val_accuracy: 0.8259
# Epoch 10/100
# 14/14 [==============================] - 0s 11ms/step - loss: 37.0817 - accuracy: 0.8195 - val_loss: 20.7760 - val_accuracy: 0.8239
# Epoch 11/100
# 14/14 [==============================] - 0s 12ms/step - loss: 16.2923 - accuracy: 0.8216 - val_loss: 9.3965 - val_accuracy: 0.8222
# Epoch 12/100
# 14/14 [==============================] - 0s 12ms/step - loss: 6.7398 - accuracy: 0.8269 - val_loss: 3.6755 - val_accuracy: 0.8360
# Epoch 13/100
# 14/14 [==============================] - 0s 13ms/step - loss: 2.6348 - accuracy: 0.8295 - val_loss: 1.3737 - val_accuracy: 0.8458
# Epoch 14/100
# 14/14 [==============================] - 0s 17ms/step - loss: 1.0588 - accuracy: 0.8342 - val_loss: 0.7209 - val_accuracy: 0.8391
# Epoch 15/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6196 - accuracy: 0.8284 - val_loss: 0.5015 - val_accuracy: 0.8154
# Epoch 16/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4616 - accuracy: 0.8239 - val_loss: 0.4229 - val_accuracy: 0.8231
# Epoch 17/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4013 - accuracy: 0.8224 - val_loss: 0.3954 - val_accuracy: 0.8242
# Epoch 18/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.3828 - accuracy: 0.8186 - val_loss: 0.3808 - val_accuracy: 0.8259
# Epoch 19/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3730 - accuracy: 0.8234 - val_loss: 0.3766 - val_accuracy: 0.8248
# Epoch 20/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3720 - accuracy: 0.8188 - val_loss: 0.3783 - val_accuracy: 0.8190
# Epoch 21/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3679 - accuracy: 0.8204 - val_loss: 0.3727 - val_accuracy: 0.8213
# Epoch 22/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3647 - accuracy: 0.8235 - val_loss: 0.3728 - val_accuracy: 0.8248
# Epoch 23/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3644 - accuracy: 0.8252 - val_loss: 0.3734 - val_accuracy: 0.8267
# Epoch 24/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3647 - accuracy: 0.8219 - val_loss: 0.3716 - val_accuracy: 0.8265
# Epoch 25/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.3627 - accuracy: 0.8241 - val_loss: 0.3718 - val_accuracy: 0.8267
# Epoch 26/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3639 - accuracy: 0.8248 - val_loss: 0.3708 - val_accuracy: 0.8274
# Epoch 27/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3620 - accuracy: 0.8236 - val_loss: 0.3699 - val_accuracy: 0.8227
# Epoch 28/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3622 - accuracy: 0.8217 - val_loss: 0.3691 - val_accuracy: 0.8213
# Epoch 29/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3603 - accuracy: 0.8241 - val_loss: 0.3697 - val_accuracy: 0.8268
# Epoch 30/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3592 - accuracy: 0.8257 - val_loss: 0.3683 - val_accuracy: 0.8270
# Epoch 31/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3593 - accuracy: 0.8237 - val_loss: 0.3682 - val_accuracy: 0.8251
# Epoch 32/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3588 - accuracy: 0.8253 - val_loss: 0.3684 - val_accuracy: 0.8219
# Epoch 33/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3725 - accuracy: 0.8242 - val_loss: 0.3686 - val_accuracy: 0.8288
# Epoch 34/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3591 - accuracy: 0.8266 - val_loss: 0.3660 - val_accuracy: 0.8313
# Epoch 35/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3589 - accuracy: 0.8309 - val_loss: 0.3665 - val_accuracy: 0.8380
# Epoch 36/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3575 - accuracy: 0.8360 - val_loss: 0.3665 - val_accuracy: 0.8429
# Epoch 37/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3586 - accuracy: 0.8365 - val_loss: 0.3663 - val_accuracy: 0.8440
# Epoch 38/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3573 - accuracy: 0.8360 - val_loss: 0.3700 - val_accuracy: 0.8409
# Epoch 39/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3590 - accuracy: 0.8339 - val_loss: 0.3659 - val_accuracy: 0.8348
# Epoch 40/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3585 - accuracy: 0.8359 - val_loss: 0.3662 - val_accuracy: 0.8415
# Epoch 41/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3565 - accuracy: 0.8358 - val_loss: 0.3664 - val_accuracy: 0.8383
# Epoch 42/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3556 - accuracy: 0.8362 - val_loss: 0.3651 - val_accuracy: 0.8454
# Epoch 43/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3552 - accuracy: 0.8404 - val_loss: 0.3646 - val_accuracy: 0.8425
# Epoch 44/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3553 - accuracy: 0.8356 - val_loss: 0.3642 - val_accuracy: 0.8409
# Epoch 45/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3530 - accuracy: 0.8376 - val_loss: 0.3670 - val_accuracy: 0.8434
# Epoch 46/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3551 - accuracy: 0.8363 - val_loss: 0.3698 - val_accuracy: 0.8417
# Epoch 47/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3562 - accuracy: 0.8323 - val_loss: 0.3662 - val_accuracy: 0.8396
# Epoch 48/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3539 - accuracy: 0.8355 - val_loss: 0.3633 - val_accuracy: 0.8423
# Epoch 49/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3536 - accuracy: 0.8358 - val_loss: 0.3626 - val_accuracy: 0.8458
# Epoch 50/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3525 - accuracy: 0.8352 - val_loss: 0.3636 - val_accuracy: 0.8448
# Epoch 51/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3530 - accuracy: 0.8362 - val_loss: 0.3626 - val_accuracy: 0.8431
# Epoch 52/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3523 - accuracy: 0.8355 - val_loss: 0.3626 - val_accuracy: 0.8409
# Epoch 53/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3539 - accuracy: 0.8317 - val_loss: 0.3634 - val_accuracy: 0.8329
# Epoch 54/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3546 - accuracy: 0.8318 - val_loss: 0.3667 - val_accuracy: 0.8328
# Epoch 55/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3540 - accuracy: 0.8313 - val_loss: 0.3654 - val_accuracy: 0.8351
# Epoch 56/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3543 - accuracy: 0.8297 - val_loss: 0.3620 - val_accuracy: 0.8279
# Epoch 57/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3522 - accuracy: 0.8288 - val_loss: 0.3630 - val_accuracy: 0.8265
# Epoch 58/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3518 - accuracy: 0.8307 - val_loss: 0.3616 - val_accuracy: 0.8316
# Epoch 59/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3505 - accuracy: 0.8320 - val_loss: 0.3614 - val_accuracy: 0.8296
# Epoch 60/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3498 - accuracy: 0.8303 - val_loss: 0.3619 - val_accuracy: 0.8293
# Epoch 61/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3509 - accuracy: 0.8308 - val_loss: 0.3621 - val_accuracy: 0.8297
# Epoch 62/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3519 - accuracy: 0.8283 - val_loss: 0.3629 - val_accuracy: 0.8296
# Epoch 63/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3512 - accuracy: 0.8266 - val_loss: 0.3618 - val_accuracy: 0.8257
# Epoch 64/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3525 - accuracy: 0.8266 - val_loss: 0.3632 - val_accuracy: 0.8296
# Epoch 65/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3505 - accuracy: 0.8291 - val_loss: 0.3619 - val_accuracy: 0.8280
# Epoch 66/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3499 - accuracy: 0.8274 - val_loss: 0.3613 - val_accuracy: 0.8240
# Epoch 67/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3529 - accuracy: 0.8256 - val_loss: 0.3610 - val_accuracy: 0.8270
# Epoch 68/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3481 - accuracy: 0.8290 - val_loss: 0.3613 - val_accuracy: 0.8253
# Epoch 69/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3496 - accuracy: 0.8277 - val_loss: 0.3623 - val_accuracy: 0.8231
# Epoch 70/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.
# Epoch 93/100
# 14/14 [==============================] - 0s 34ms/step - loss: 0.3490 - accuracy: 0.8294 - val_loss: 0.3594 - val_accuracy: 0.8227
# Epoch 94/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.3479 - accuracy: 0.8290 - val_loss: 0.3611 - val_accuracy: 0.8228
# Epoch 95/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.3457 - accuracy: 0.8290 - val_loss: 0.3610 - val_accuracy: 0.8188
# Epoch 96/100
# 14/14 [==============================] - 0s 35ms/step - loss: 0.3483 - accuracy: 0.8253 - val_loss: 0.3638 - val_accuracy: 0.8197
# Epoch 97/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.3469 - accuracy: 0.8289 - val_loss: 0.3622 - val_accuracy: 0.8135
# Epoch 98/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.3466 - accuracy: 0.8250 - val_loss: 0.3619 - val_accuracy: 0.8190
# Epoch 99/100
# 14/14 [==============================] - 0s 22ms/step - loss: 0.3451 - accuracy: 0.8283 - val_loss: 0.3612 - val_accuracy: 0.8165
# Epoch 100/100
# 14/14 [==============================] - 0s 34ms/step - loss: 0.3468 - accuracy: 0.8277 - val_loss: 0.3607 - val_accuracy: 0.8190
# val_acc: 0.818977415561676
# val_loss: 0.3606611490249634

# %%
# Save model

model.save('/content/drive/MyDrive/GDSC-AI/model')

# %%
# Load model

# from keras import models
# model = models.load_model('/content/drive/MyDrive/GDSC-AI/model')
# 
# model.fit(X_test, Y_test)

# %% [markdown]
# ### Step4. 模型預測
# 模型訓練完之後就可以拿來使用了。
#
# 直接執行 `model.predict()` 來預測我們的 X_test ，並且和 Y_test 進行比較。
#
# 預測結果 Y_predict 會是一個機率矩陣，**代表 X_test 當中每比資料年收入 >50K 的機率**，我們自己設定一個閥直，如果機率大於0.5我們就設定他的年收入一定 >50K。
#
# ```python
# Y_predict_bin = np.where(Y_predict > 0.5, 1, 0)
# ```
#
# 再來，我們用 Confusion matrix 看看模型的預測狀況。

# %%
#@title Predict

from sklearn.metrics import confusion_matrix

# Predict
Y_predict = model.predict(X_test)

# Confusion matrix (CM)
threshold = 0.31

Y_predict_bin = np.where(Y_predict > threshold, 1, 0)   #二元化訓練結果
result = confusion_matrix(Y_test, Y_predict_bin)  #生成CM

# Plot CM
result_df = pd.DataFrame(result, range(2), range(2))
sns.heatmap(result_df, annot=True, fmt="g")
plt.ylabel('Real Value')
plt.xlabel('Predicted Value')

# Validating the errors
alpha_err = result[0,1] / (result[0,0] + result[0,1]) # 偽陽性機率
beta_err = result[1,0] / (result[1,0] + result[1,1])  # 偽陰性機率
print("alpha_error : {:.2f}".format(alpha_err))
print("beta_error : {:.2f}".format(beta_err))
mse = np.sqrt((alpha_err*alpha_err+beta_err*beta_err)/2)
print("MSE: {:.2f}".format(mse))

plt.show()
# Out:
# 509/509 [==============================] - 3s 6ms/step
# alpha_error : 0.22
# beta_error : 0.16
# MSE: 0.20
